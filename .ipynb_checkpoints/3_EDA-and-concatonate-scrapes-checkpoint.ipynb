# %% [markdown]
# ## Data Cleaning and Concatonating Scrape CSVs
# _Author: Rachel Koenig_
# ____

# %% [markdown]
# Imports

# %%
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# Define a function to remove html

# %%
def remove_html(text):
    try:  
        soup = BeautifulSoup(text, 'lxml')  # Instantiate BeautifulSoup
        html_free = soup.get_text(strip=True)  # Strip html, leaving just text 
        return html_free
    except:  
        return "missing"  # if there is nulls in the column, fill with "missing" string

# %% [markdown]
# Define a function to clean a dataframe from the  scrape:

# %%
def EDA(df):
    # Remove html and strip off brackets and 'Color:' from color column
    df['color'] = df['color'].apply(lambda x: remove_html(x)).str.replace(']', '').str.replace('[', '').str.replace('Color:', '')
    
    # Replace escape characters and white space in Category column 
    df['category'] = df['category'].str.replace('\n', '').str.replace('  ', '')
    
    # Split Categroy column on the '›' symbol, up to 6 times and return them in a new df where each split is a new column 
    category = df['category'].str.split("›", n=6, expand=True)
    
    # Rename each category split column and add it onto the original df
    df['department'] = category[0]
    df['demographic'] = category[1]
    df['division'] = category[2]
    df['category'] = category[3]
    df['subcategory'] = category[4]
    df['type'] = category[5]
    df['detail_type'] = category[6]
    
    # Remove special characters from the description column 
    df['description'] = df['description'].str.replace('\t', '').str.replace('\n', '')
    
    # Remove html and strip off brackets from details column
    df['details'] = df['details'].apply(lambda x: remove_html(x)).str.replace(']', '').str.replace('[', '')
   
    #Remove html and cut off 'Size:' from the size column 
    df['size'] = df['size'].apply(lambda x: remove_html(x)).str.replace('Size:', '')
    
    return df.head()

# %% [markdown]
# Read in csv of first 8000 scrapes.

# %%
df1 = pd.read_csv('scrapes/product8000.csv', index_col=[0])

# %%
# Check first 5 rows 
df1.head()
# Out:
#          asin                                           category  \
# 0  0000031887  Sports & Outdoors\n            \n\n\n         ...
# 1  0123456479  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 2  1608299953  Software\n            \n\n\n             ›\n  ...
# 3  1617160377  Software\n            \n\n\n             ›\n  ...
# 4  B00001W0KA  Toys & Games\n            \n\n\n             ›...
#
#                                                color  \
# 0                                        unavailable
# 1                                        unavailable
# 2                                        unavailable
# 3                                        unavailable
# 4  <div class="a-section a-spacing-small" id="var...
#
#                                          description details  \
# 0  This fits your .\n    \n\n\n Make sure this fi...      []
# 1  This fits your .\n    \n\n\n Make sure this fi...      []
# 2  Access for up to 5 family members\n\t\t\t\t\t\...      []
# 3  Access for up to 5 family members\n\t\t\t\t\t\...      []
# 4  Lead Free\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n \n\t...      []
#
#                                                 name  \
# 0   Mystiqueshapes Girls Ballet Tutu Neon Lime Green
# 1  SHINING IMAGE HUGE PINK LEATHER JEWELRY BOX / ...
# 2       Learn French: Rosetta Stone French - Level 1
# 3     Learn Italian: Rosetta Stone Italian - Level 1
# 4      Buzz Lightyear Boy's Deluxe Toy Story Costume
#
#                                                 size
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  <div class="a-section a-spacing-base variation...

# %% [markdown]
# Read in csv of next 2000 scrapes followed by the rest of the chunks.  Each csv is a slightly different size just due to scraper cooperation and available time to run the scraper each time.

# %%
df2 = pd.read_csv('scrapes/product20000.csv', index_col=[0])
df2.head()
# Out:
#          asin                                           category  \
# 0  B006W71WJI  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 1  B006W8QR56  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 2  B006W8WLTW  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 3  B006W8WMP0                                   unknown category
# 4  B006WANIVK  Clothing, Shoes & Jewelry\n            \n\n\n ...
#
#                                                color  \
# 0  <div class="a-section a-spacing-small" id="var...
# 1  <div class="a-section a-spacing-small" id="var...
# 2  <div class="a-section a-spacing-small" id="var...
# 3                                      unknown color
# 4  <div class="a-section a-spacing-small" id="var...
#
#                                          description details  \
# 0  100% Leather\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n \...      []
# 1  IDEAL SIZE -Drawstring backpacks come in one s...      []
# 2  100% Interlock Cotton\n\t\t\t\t\t\t\t\n\t\t\t\...      []
# 3                                    unknown details     NaN
# 4  90% Cotton | 10% Rayon\n\t\t\t\t\t\t\t\n\t\t\t...      []
#
#                                                 name  \
# 0                Dansko Women's Valerie Pull-Up Clog
# 1  Mato & Hash Drawstring Bulk Bags Cinch Sacks B...
# 2   Luvable Friends Baby Sayings Bodysuit – Wild Boy
# 3                               unknown product name
# 4  Funfash Plus Size Women Open Angel Sleeve Cold...
#
#                                                 size
# 0  <div class="a-section a-spacing-small" id="var...
# 1  <div class="a-section a-spacing-base variation...
# 2  <div class="a-section a-spacing-small" id="var...
# 3                                                NaN
# 4  <div class="a-section a-spacing-base variation...

# %%
df3 = pd.read_csv('scrapes/product21180.csv', index_col=[0])
df3.head()
# Out:
#          asin                                           category  \
# 0  B00B8ZJ8U4  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 1  B00B93TTHM  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 2  B00B93UDRW  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 3  B00B93W5R8                                   unknown category
# 4  B00B98MPWS  Clothing, Shoes & Jewelry\n            \n\n\n ...
#
#                                                color  \
# 0                                        unavailable
# 1  <div class="a-section a-spacing-small" id="var...
# 2  <div class="a-section a-spacing-small" id="var...
# 3                                      unknown color
# 4  <div class="a-section a-spacing-small" id="var...
#
#                                          description  \
# 0  THIS PRICE IS FOR TWO BRACELETS!\n\t\t\t\t\t\t...
# 1  100% Polyester\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n...
# 2  65% Cotton / 35% Polyester\n\t\t\t\t\t\t\t\n\t...
# 3                                    unknown details
# 4  Synthetic\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n \n\t...
#
#                                              details  \
# 0  [<td class="a-span7 a-size-base">\n           ...
# 1                                                 []
# 2                                                 []
# 3                                                NaN
# 4                                                 []
#
#                                                 name  \
# 0  JOTW 2 Pieces of Goldtone with Clear Iced Out ...
# 1  Doublju Classic Slim Fit Sleeveless Sexy Bodyc...
# 2  Doublju Slim Fit Ribbed Knit Button Down Henle...
# 3                               unknown product name
# 4    Merrell Men's Ascend Glove Minimal Running Shoe
#
#                                                 size
# 0                                                NaN
# 1  <div class="a-section a-spacing-small" id="var...
# 2  <div class="a-section a-spacing-small" id="var...
# 3                                                NaN
# 4  <div class="a-section a-spacing-base variation...

# %%
df4 = pd.read_csv('scrapes/product23033.csv', index_col=[0])
df4.head()
# Out:
#          asin                                           category  \
# 0  B00CWU9H9G  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 1  B00CWUC9TQ  Sports & Outdoors\n            \n\n\n         ...
# 2  B00CWVE9KM  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 3  B00CWVUVMC  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 4  B00CWW1Q1Q  Clothing, Shoes & Jewelry\n            \n\n\n ...
#
#                                                color  \
# 0  <div class="a-section a-spacing-small" id="var...
# 1  <div class="a-section a-spacing-small" id="var...
# 2  <div class="a-section a-spacing-small" id="var...
# 3                                        unavailable
# 4  <div class="a-section a-spacing-small" id="var...
#
#                                          description  \
# 0  100% Rayon\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n \n\...
# 1  Imported\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n \n\t\...
# 2  Scoop neck short sleeve top, super comfy Plus ...
# 3  CLASSIC DESIGN: PU leather band, roman number ...
# 4  Chiffon Sheer Long Sleeves Blouse\n\t\t\t\t\t\...
#
#                                              details  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [<td class="a-span7 a-size-base">\n           ...
# 4                                                 []
#
#                                                 name  \
# 0  Rayon Short Sleeves Flyaway Cardigan Shawl Col...
# 1  Plus Size Yoga Long Stretch Pants 92% Cotton, ...
# 2  Hollywood Star Fashion Women's Short Cap Sleev...
# 3  Mens Quartz Watch, Roman Numeral Business Casu...
# 4  Basic Long Sleeves Sheer Chiffon Blouse with P...
#
#                                                 size
# 0  <div class="a-section a-spacing-small" id="var...
# 1  <div class="a-section a-spacing-small" id="var...
# 2  <div class="a-section a-spacing-base variation...
# 3                                                NaN
# 4  <div class="a-section a-spacing-small" id="var...

# %% [markdown]
# Create a list of DataFrames called `dataframes` to be concatonated & then concat them along the row axis and call the new DataFrame `total_product`.

# %%
dataframes = [df1, df2, df3, df4] 

total_product = pd.concat(dataframes, axis=0)

# %%
# Check the shape of new combined DataFrame
total_product.shape
# Out:
# (17033, 7)

# %% [markdown]
# Call the EDA data cleaning function on the `total_product` DataFrame.

# %%
EDA(total_product)
# Out:
#          asin                      category           color  \
# 0  0000031887                        Dance      unavailable
# 1  0123456479   Jewelry Boxes & Organizers      unavailable
# 2  1608299953                          None     unavailable
# 3  1617160377                          None     unavailable
# 4  B00001W0KA                          None  Buzz Lightyear
#
#                                          description details  \
# 0  This fits your .     Make sure this fitsby ent...
# 1  This fits your .     Make sure this fitsby ent...
# 2  Access for up to 5 family members Download act...
# 3  Access for up to 5 family members Download act...
# 4  Lead Free Child (4-6 & 7-8) Includes: Bodysuit...
#
#                                                 name  \
# 0   Mystiqueshapes Girls Ballet Tutu Neon Lime Green
# 1  SHINING IMAGE HUGE PINK LEATHER JEWELRY BOX / ...
# 2       Learn French: Rosetta Stone French - Level 1
# 3     Learn Italian: Rosetta Stone Italian - Level 1
# 4      Buzz Lightyear Boy's Deluxe Toy Story Costume
#
#                                                 size  \
# 0                                            missing
# 1                                            missing
# 2                                            missing
# 3                                            missing
# 4  SelectM(3T-4T)3T-4TSmall (4-6)Medium (7-8)Medi...
#
#                    department                          demographic  \
# 0          Sports & Outdoors                     Sports & Fitness
# 1  Clothing, Shoes & Jewelry    Shoe, Jewelry & Watch Accessories
# 2                   Software                Education & Reference
# 3                   Software                Education & Reference
# 4               Toys & Games              Dress Up & Pretend Play
#
#                 division    subcategory     type detail_type
# 0          Other Sports       Clothing    Girls       Skirts
# 1   Jewelry Accessories   Jewelry Boxes     None        None
# 2              Languages           None     None        None
# 3              Languages           None     None        None
# 4               Costumes           None     None        None

# %% [markdown]
# Check for nulls.

# %%
total_product.isnull().sum()
# Out:
# asin               0
# category       12260
# color              0
# description        0
# details            0
# name               0
# size               0
# department         0
# demographic    12009
# division       12077
# subcategory    13867
# type           16054
# detail_type    16619
# dtype: int64

# %% [markdown]
# Check value counts for `department` to see how many unknown categories exist.

# %%
total_product['department'].value_counts(dropna=False)
# Out:
# unknown category              12009
# Clothing, Shoes & Jewelry      4690
# Sports & Outdoors               226
# Toys & Games                     36
# Health & Household               18
# Arts, Crafts & Sewing            13
# Beauty & Personal Care           10
# Electronics                       8
# Home & Kitchen                    7
# Tools & Home Improvement          6
# Baby Products                     5
# Software                          2
# Purchase Circles                  1
# Office Products                   1
# Automotive                        1
# Name: department, dtype: int64

# %% [markdown]
# Save the rows that were not unknown as a new DataFrame called `robot_free_df`.

# %%
robot_free_df = (total_product[total_product['department'] != 'unknown category'])

# %%
# Check shape with dropped rows
robot_free_df.shape
# Out:
# (5024, 13)

# %%
# Check data types 
robot_free_df.dtypes
# Out:
# asin           object
# category       object
# color          object
# description    object
# details        object
# name           object
# size           object
# department     object
# demographic    object
# division       object
# subcategory    object
# type           object
# detail_type    object
# dtype: object

# %% [markdown]
# Check if there are still nulls elsewhere.  In this case, they are expected because some products had more category types than others which expanded out to more columns leaving products with less categories having empty cells.

# %%
robot_free_df.isnull().sum()
# Out:
# asin              0
# category        251
# color             0
# description       0
# details           0
# name              0
# size              0
# department        0
# demographic       0
# division         68
# subcategory    1858
# type           4045
# detail_type    4610
# dtype: int64

# %% [markdown]
# Read in additional scrape csvs that definitely were not affected by the anti-robot pages.

# %%
norobotdf = pd.read_csv('scrapes/product14000.csv', index_col=[0])
print(norobotdf.shape) #Check shape 
norobotdf.head()  # Check first 5 rows
# Out:
# (5466, 7)
#          asin                                           category  \
# 0  B003ZVQQVS  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 1  B003ZVZDKS  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 2  B003ZVZH5E  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 3  B003ZW0X2K  Sports & Outdoors\n            \n\n\n         ...
# 4  B003ZW163K  Clothing, Shoes & Jewelry\n            \n\n\n ...
#
#                                                color  \
# 0                                        unavailable
# 1  <div class="a-section a-spacing-small" id="var...
# 2  <div class="a-section a-spacing-small" id="var...
# 3  <div class="a-section a-spacing-small" id="var...
# 4  <div class="a-section a-spacing-small" id="var...
#
#                                          description details  \
# 0  This fits your .\n    \n\n\n Make sure this fi...      []
# 1  90% cotton 10% polyester\n\t\t\t\t\t\t\t\n\t\t...      []
# 2  100% Cotton\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n \n...      []
# 3  100% Polyester\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n...      []
# 4  100% Cotton\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n \n...      []
#
#                                                 name  \
# 0  High Sierra A.T. Ultimate Access Carry-On Whee...
# 1               Champion Women's Favorite V-Neck Tee
# 2              Champion Women's Favorite V-Neck Tank
# 3  Champion Women's Absolute Workout Pant Short L...
# 4                    Champion Women's Favorite Short
#
#                                                 size
# 0                                                NaN
# 1  <div class="a-section a-spacing-base variation...
# 2  <div class="a-section a-spacing-base variation...
# 3  <div class="a-section a-spacing-small" id="var...
# 4  <div class="a-section a-spacing-base variation...

# %%
# Clean DataFrame with EDA function 
EDA(norobotdf)
# Out:
#          asin                category        color  \
# 0  B003ZVQQVS                    None  unavailable
# 1  B003ZVZDKS                 Active   Oxford Gray
# 2  B003ZVZH5E   Tops, Tees & Blouses         White
# 3  B003ZW0X2K                   Yoga         Black
# 4  B003ZW163K                 Active   Oxford Gray
#
#                                          description details  \
# 0  This fits your .     Make sure this fitsby ent...
# 1  90% cotton 10% polyester Imported Not applicab...
# 2  100% Cotton Imported tank-top-and-cami-shirts ...
# 3  100% Polyester pants closure Silky performance...
# 4  100% Cotton Imported shorts closure Machine wa...
#
#                                                 name  \
# 0  High Sierra A.T. Ultimate Access Carry-On Whee...
# 1               Champion Women's Favorite V-Neck Tee
# 2              Champion Women's Favorite V-Neck Tank
# 3  Champion Women's Absolute Workout Pant Short L...
# 4                    Champion Women's Favorite Short
#
#                                                 size  \
# 0                                            missing
# 1  SelectX-SmallSmallMediumLargeX-LargeXX-LargeSe...
# 2  SelectSmallMediumLargeX-LargeXX-LargeSelectif(...
# 3                                              Small
# 4  SelectSmallLargeX-LargeSelectif(typeof(Twister...
#
#                    department              demographic              division  \
# 0  Clothing, Shoes & Jewelry    Luggage & Travel Gear              Backpacks
# 1  Clothing, Shoes & Jewelry                    Women              Clothing
# 2  Clothing, Shoes & Jewelry                    Women              Clothing
# 3          Sports & Outdoors         Sports & Fitness    Exercise & Fitness
# 4  Clothing, Shoes & Jewelry                    Women              Clothing
#
#             subcategory     type detail_type
# 0                  None     None        None
# 1  Active Shirts & Tees     None        None
# 2         Tanks & Camis     None        None
# 3             Clothing    Women        Pants
# 4         Active Shorts     None        None

# %%
norobotdf2 = pd.read_csv('scrapes/product8534.csv', index_col=[0])
print(norobotdf2.shape)  # Check shape 
norobotdf2.head()  # Check first 5 rows
# Out:
# (534, 7)
#          asin                                           category  \
# 0  B003QOJB3O  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 1  B003QORIMA  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 2  B003QOZ732                                   unknown category
# 3  B003QSIMRQ  Clothing, Shoes & Jewelry\n            \n\n\n ...
# 4  B003QSVLWE  Clothing, Shoes & Jewelry\n            \n\n\n ...
#
#                                                color  \
# 0  <div class="a-section a-spacing-small" id="var...
# 1  <div class="a-section a-spacing-base variation...
# 2                                      unknown color
# 3  <div class="a-section a-spacing-small" id="var...
# 4  <div class="a-section a-spacing-small" id="var...
#
#                                          description details  \
# 0  100% polyster\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n ...      []
# 1  Cotton & Polyester\n\t\t\t\t\t\t\t\n\t\t\t\t\t...      []
# 2                                    unknown details     NaN
# 3  100% Polyester\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n...      []
# 4  These soft and comfortable flannel pajamas hav...      []
#
#                                                 name  \
# 0  Sport-Tek Women's Side Blocked Performance Pol...
# 1      Port Authority® Ladies Silk Touch™ Polo. L500
# 2                               unknown product name
# 3  eVogues Women's Sexy O-Ring Necklace Sleeveles...
# 4                              Men's Flannel Pajamas
#
#                                                 size
# 0  <div class="a-section a-spacing-base variation...
# 1  <div class="a-section a-spacing-base variation...
# 2                                                NaN
# 3  <div class="a-section a-spacing-small" id="var...
# 4  <div class="a-section a-spacing-base variation...

# %%
# Clean DataFrame with EDA function 
EDA(norobotdf2)
# Out:
#          asin                category  \
# 0  B003QOJB3O   Tops, Tees & Blouses
# 1  B003QORIMA   Tops, Tees & Blouses
# 2  B003QOZ732                    None
# 3  B003QSIMRQ   Tops, Tees & Blouses
# 4  B003QSVLWE         Sleep & Lounge
#
#                                                color  \
# 0                                   Light Pink/White
# 1  Deep BerryRedTropical PinkSunflower YellowTurq...
# 2                                      unknown color
# 3                                              Black
# 4                                              Black
#
#                                          description  details  \
# 0  100% polyster Button closure 3.8-ounce, 100% p...
# 1  Cotton & Polyester Button closure An enduring ...
# 2                                    unknown details  missing
# 3  100% Polyester Made in USA 1XL=Size 13/14, 2XL...
# 4  These soft and comfortable flannel pajamas hav...
#
#                                                 name  \
# 0  Sport-Tek Women's Side Blocked Performance Pol...
# 1      Port Authority® Ladies Silk Touch™ Polo. L500
# 2                               unknown product name
# 3  eVogues Women's Sexy O-Ring Necklace Sleeveles...
# 4                              Men's Flannel Pajamas
#
#                                                 size  \
# 0  SelectX-SmallSmallMediumLargeX-LargeXX-Large3X...
# 1  SelectXSX-SmallSSmallMMediumLLargeX-LargeXX-La...
# 2                                            missing
# 3                                                 2X
# 4  SelectSmallMediumExtra Large (2X)Extra Large (...
#
#                    department demographic    division    subcategory  type  \
# 0  Clothing, Shoes & Jewelry       Women    Clothing           Polos  None
# 1  Clothing, Shoes & Jewelry       Women    Clothing           Polos  None
# 2            unknown category        None        None           None  None
# 3  Clothing, Shoes & Jewelry       Women    Clothing   Tanks & Camis  None
# 4  Clothing, Shoes & Jewelry         Men    Clothing      Sleep Sets  None
#
#   detail_type
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None

# %%
norobotdf3 = pd.read_csv('scrapes/redo1.csv', index_col=[0])
print(norobotdf3.shape)  # Check shape 
norobotdf3.head()  # Check first 5 rows
# Out:
# (598, 13)
#            asin                      category        color  \
# 177  B000H6AQ0Q                        Women   unavailable
# 178  B000H6BYI4   Jewelry Boxes & Organizers   unavailable
# 179  B000H6DWZC   Jewelry Boxes & Organizers   unavailable
# 180  B000H703V2                       Oxfords      missing
# 181  B000H7YCE6        Bags, Cases & Sleeves       missing
#
#                                            description  details  \
# 177  This fits your .     Make sure this fitsby ent...  missing
# 178  This fits your .     Make sure this fitsby ent...  missing
# 179  This fits your .     Make sure this fitsby ent...  missing
# 180  100% Full-grain leather,Leather,Nubuck Importe...  missing
# 181  This fits your .     Make sure this fitsby ent...  missing
#
#                                                   name     size  \
# 177      Timex 1440 Sports Digital Mid Size Black/Pink  missing
# 178  Caddy Bay Collection Wide Slot Jewelry Ring Di...  missing
# 179                             Fairy Tale Jewelry Box  missing
# 180  Ecco Men's Track II Low GORE-TEX waterproof ou...  missing
# 181                          High Sierra Loop Backpack  missing
#
#                      department                          demographic  \
# 177          Sports & Outdoors                   Outdoor Recreation
# 178  Clothing, Shoes & Jewelry    Shoe, Jewelry & Watch Accessories
# 179  Clothing, Shoes & Jewelry    Shoe, Jewelry & Watch Accessories
# 180  Clothing, Shoes & Jewelry                                  Men
# 181                Electronics              Computers & Accessories
#
#                   division    subcategory           type detail_type
# 177      Outdoor Clothing    Accessories   Sport Watches         NaN
# 178   Jewelry Accessories   Jewelry Boxes            NaN         NaN
# 179   Jewelry Accessories   Jewelry Boxes            NaN         NaN
# 180                 Shoes             NaN            NaN         NaN
# 181    Laptop Accessories       Backpacks            NaN         NaN

# %% [markdown]
# Create a list of all clean and robot free DataFrames to be concatonated called `clean_dfs` and call the new combined DataFrame `robot_free_df`

# %%
clean_dfs = [robot_free_df, norobotdf, norobotdf2, norobotdf3]
robot_free_df = pd.concat(clean_dfs, axis=0)  # Axis = 0, stack on top of each other 
robot_free_df.shape  # Check that shape matches the size of all previous rows being added together
# Out:
# (11622, 13)

# %% [markdown]
# Save combined dfs to a csv in the data folder.

# %%
# robot_free_df.to_csv('data/robot_free.csv')

# %% [markdown]
# Read in the csv we just saved.

# %%
robot_free_df = pd.read_csv('scrapes/robot_free.csv', index_col=[0])
robot_free_df.head()  # Check the first 5 rows
# Out:
#    Unnamed: 0.1        asin                      category           color  \
# 0             0  0000031887                        Dance      unavailable
# 1             1  0123456479   Jewelry Boxes & Organizers      unavailable
# 2             2  1608299953                           NaN     unavailable
# 3             3  1617160377                           NaN     unavailable
# 4             4  B00001W0KA                           NaN  Buzz Lightyear
#
#                                          description details  \
# 0  This fits your .     Make sure this fitsby ent...     NaN
# 1  This fits your .     Make sure this fitsby ent...     NaN
# 2  Access for up to 5 family members Download act...     NaN
# 3  Access for up to 5 family members Download act...     NaN
# 4  Lead Free Child (4-6 & 7-8) Includes: Bodysuit...     NaN
#
#                                                 name  \
# 0   Mystiqueshapes Girls Ballet Tutu Neon Lime Green
# 1  SHINING IMAGE HUGE PINK LEATHER JEWELRY BOX / ...
# 2       Learn French: Rosetta Stone French - Level 1
# 3     Learn Italian: Rosetta Stone Italian - Level 1
# 4      Buzz Lightyear Boy's Deluxe Toy Story Costume
#
#                                                 size  \
# 0                                            missing
# 1                                            missing
# 2                                            missing
# 3                                            missing
# 4  SelectM(3T-4T)3T-4TSmall (4-6)Medium (7-8)Medi...
#
#                    department                          demographic  \
# 0          Sports & Outdoors                     Sports & Fitness
# 1  Clothing, Shoes & Jewelry    Shoe, Jewelry & Watch Accessories
# 2                   Software                Education & Reference
# 3                   Software                Education & Reference
# 4               Toys & Games              Dress Up & Pretend Play
#
#                 division    subcategory     type detail_type
# 0          Other Sports       Clothing    Girls       Skirts
# 1   Jewelry Accessories   Jewelry Boxes      NaN         NaN
# 2              Languages            NaN      NaN         NaN
# 3              Languages            NaN      NaN         NaN
# 4               Costumes            NaN      NaN         NaN

# %% [markdown]
# Check what percentage of each column are null.

# %%
robot_free_df.isnull().mean()
# Out:
# Unnamed: 0.1    0.000000
# asin            0.000000
# category        0.122221
# color           0.000069
# description     0.000000
# details         0.558057
# name            0.000000
# size            0.000000
# department      0.000000
# demographic     0.079673
# division        0.092026
# subcategory     0.408798
# type            0.815056
# detail_type     0.917925
# dtype: float64

# %% [markdown]
# Read in new csvs from the rescrapes.

# %%
redo2 = pd.read_csv('scrapes/redo2.csv', index_col=[0])
redo3 = pd.read_csv('scrapes/redo3.csv', index_col=[0])
redo4 = pd.read_csv('scrapes/redo4.csv', index_col=[0])
redo5 = pd.read_csv('scrapes/redo5.csv', index_col=[0])
redo6 = pd.read_csv('scrapes/redo6.csv', index_col=[0])

# %% [markdown]
# Concatonate all the new DataFrames with the last saved DataFrame on top of one another.

# %%
# List of DataFrames to concatonate 
redo_dfs = [robot_free_df, redo2, redo3, redo4, redo5, redo6]

# %%
robot_free_df6 = pd.concat(redo_dfs, axis=0, # Stack dataframes on along the row index,
                           sort=True,        # Sort values  
                           ignore_index=True)  # Ignore the previous indexes so that new index goes in order 0 to n
robot_free_df6.shape  # Check that shape matches number of rows added together
# Out:
# (17843, 14)

# %%
robot_free_df6.drop(columns='Unnamed: 0.1', inplace=True)  # Drop unnamed column

# %% [markdown]
# Save new DataFrame to a csv.  Line is commented out so as to not override the save when notebook is rerun later.

# %%
# robot_free_df6.to_csv('data/robot_free6.csv', index=False)

# %%
# Check first 5 rows 
robot_free_df6.head()
# Out:
#          asin                      category           color  \
# 0  0000031887                        Dance      unavailable
# 1  0123456479   Jewelry Boxes & Organizers      unavailable
# 2  1608299953                           NaN     unavailable
# 3  1617160377                           NaN     unavailable
# 4  B00001W0KA                           NaN  Buzz Lightyear
#
#                            demographic                  department  \
# 0                    Sports & Fitness           Sports & Outdoors
# 1   Shoe, Jewelry & Watch Accessories   Clothing, Shoes & Jewelry
# 2               Education & Reference                    Software
# 3               Education & Reference                    Software
# 4             Dress Up & Pretend Play                Toys & Games
#
#                                          description detail_type details  \
# 0  This fits your .     Make sure this fitsby ent...      Skirts     NaN
# 1  This fits your .     Make sure this fitsby ent...         NaN     NaN
# 2  Access for up to 5 family members Download act...         NaN     NaN
# 3  Access for up to 5 family members Download act...         NaN     NaN
# 4  Lead Free Child (4-6 & 7-8) Includes: Bodysuit...         NaN     NaN
#
#                 division                                               name  \
# 0          Other Sports    Mystiqueshapes Girls Ballet Tutu Neon Lime Green
# 1   Jewelry Accessories   SHINING IMAGE HUGE PINK LEATHER JEWELRY BOX / ...
# 2              Languages       Learn French: Rosetta Stone French - Level 1
# 3              Languages     Learn Italian: Rosetta Stone Italian - Level 1
# 4               Costumes      Buzz Lightyear Boy's Deluxe Toy Story Costume
#
#                                                 size    subcategory     type
# 0                                            missing      Clothing    Girls
# 1                                            missing  Jewelry Boxes      NaN
# 2                                            missing            NaN      NaN
# 3                                            missing            NaN      NaN
# 4  SelectM(3T-4T)3T-4TSmall (4-6)Medium (7-8)Medi...            NaN      NaN

# %% [markdown]
# Read in final csv from rescraping.

# %%
redo7 = pd.read_csv('scrapes/redo7.csv', index_col=[0])
redo7.head()
# Out:
#           asin                                               name
# 0   B007WA2TCS  Allegra K Women V Neck Sleeveless Striped Pane...
# 2   B007WA2VB2  Allegra K Women Scoop Neck Drawstring Mid-Calf...
# 3   B007WA2ZTA  Allegra K Women Peter Pan 3/4 Sleeve Summer To...
# 4   B007WA3558  Allegra K Lady Ruffle Tie Neck Short Sleeves B...
# 10  B007WA3GMK  Allegra K Women Sweet Layered Tiered Crochet D...

# %% [markdown]
# Concatonate final scrape with the rest of the scrapes, call it `final_df`.

# %%
final_df = pd.concat([robot_free_df6, redo7], sort=True).fillna(0)  # fill any empty cells with 0s.

# %% [markdown]
# Check first 5 rows to make sure asins are in order and everything looks as expected.

# %%
final_df.head()
# Out:
#          asin                      category           color  \
# 0  0000031887                        Dance      unavailable
# 1  0123456479   Jewelry Boxes & Organizers      unavailable
# 2  1608299953                             0     unavailable
# 3  1617160377                             0     unavailable
# 4  B00001W0KA                             0  Buzz Lightyear
#
#                            demographic                  department  \
# 0                    Sports & Fitness           Sports & Outdoors
# 1   Shoe, Jewelry & Watch Accessories   Clothing, Shoes & Jewelry
# 2               Education & Reference                    Software
# 3               Education & Reference                    Software
# 4             Dress Up & Pretend Play                Toys & Games
#
#                                          description detail_type details  \
# 0  This fits your .     Make sure this fitsby ent...      Skirts       0
# 1  This fits your .     Make sure this fitsby ent...           0       0
# 2  Access for up to 5 family members Download act...           0       0
# 3  Access for up to 5 family members Download act...           0       0
# 4  Lead Free Child (4-6 & 7-8) Includes: Bodysuit...           0       0
#
#                 division                                               name  \
# 0          Other Sports    Mystiqueshapes Girls Ballet Tutu Neon Lime Green
# 1   Jewelry Accessories   SHINING IMAGE HUGE PINK LEATHER JEWELRY BOX / ...
# 2              Languages       Learn French: Rosetta Stone French - Level 1
# 3              Languages     Learn Italian: Rosetta Stone Italian - Level 1
# 4               Costumes      Buzz Lightyear Boy's Deluxe Toy Story Costume
#
#                                                 size    subcategory     type
# 0                                            missing      Clothing    Girls
# 1                                            missing  Jewelry Boxes        0
# 2                                            missing              0        0
# 3                                            missing              0        0
# 4  SelectM(3T-4T)3T-4TSmall (4-6)Medium (7-8)Medi...              0        0

# %% [markdown]
# Check number off final rows, columns should still be the same.

# %%
final_df.shape
# Out:
# (19766, 13)

# %% [markdown]
# Check value counts for `name` column to see how many are still unknown.

# %%
final_df['name'].value_counts().head()
# Out:
# unknown product name                            1161
# Birkenstock Women's Mayari Birko-Flor Sandal       7
# MG Low Profile Dyed Cotton Twill Cap               7
# ASICS Women's GEL-Noosa Tri 8 Running Shoe         6
# Reebok Women's Easytone                            6
# Name: name, dtype: int64

# %% [markdown]
# Drop the unknown product name rows.

# %%
final_df[final_df['name'] == 'unknown product name'].head()
# Out:
#             asin category          color demographic        department  \
# 5038  B003ZYUD0K        0  unknown color           0  unknown category
# 5046  B00400N6WU        0  unknown color           0  unknown category
# 5047  B00400N6XE        0  unknown color           0  unknown category
# 5048  B00400N6YS        0  unknown color           0  unknown category
# 5050  B00400WLYY        0  unknown color           0  unknown category
#
#           description detail_type  details division                  name  \
# 5038  unknown details           0  missing        0  unknown product name
# 5046  unknown details           0  missing        0  unknown product name
# 5047  unknown details           0  missing        0  unknown product name
# 5048  unknown details           0  missing        0  unknown product name
# 5050  unknown details           0  missing        0  unknown product name
#
#          size subcategory type
# 5038  missing           0    0
# 5046  missing           0    0
# 5047  missing           0    0
# 5048  missing           0    0
# 5050  missing           0    0

# %% [markdown]
# Check value counts for `asin` column.

# %%
final_df['asin'].value_counts().head(25)
# Out:
# B001A3Y912    2
# B009SRN6T8    2
# B007NNX43W    2
# B002FQKARA    2
# B0099JXX5M    2
# B003MSO2RY    2
# B007VFHOQ0    2
# B001IOETPO    2
# B007WGGPCC    2
# B007ST73DS    2
# B00A73AKBY    2
# B009AFGZP0    2
# B00A86Q2HQ    2
# B001QCZ3E4    2
# B0086H00Y0    2
# B0083ZD34O    2
# B001SASX14    2
# B001BZ2DQC    2
# B002U5CVC8    2
# B009RV0PSA    2
# B009ZDEXQK    2
# B0085E311S    2
# B00361E9OS    2
# B00A7Y4HSK    2
# B0087AY0VK    2
# Name: asin, dtype: int64

# %%
final_df['asin'].value_counts().tail(25)
# Out:
# B006YFWL0M    1
# B00005JHKE    1
# B004ARQ5A8    1
# B00FXE3154    1
# B00BY2ER5W    1
# B001HLE570    1
# B004SUANZU    1
# B005X4TUZY    1
# B00028B4U0    1
# B000AOZJZM    1
# B003XDTOFS    1
# B0007QMK2S    1
# B006TQLQX4    1
# B007IS5ITU    1
# B0054403MM    1
# B00B3OY2BU    1
# B0041YZKYW    1
# B00F4WT960    1
# B008ELMWMG    1
# B005FKVEN2    1
# B003VPA2YU    1
# B000TR4TI8    1
# B00EHJ5FT6    1
# B004HVB2V4    1
# B00EFD44DC    1
# Name: asin, dtype: int64

# %% [markdown]
# The value counts show me that some products got scraped twice so I drop the duplicates.

# %%
final_df.drop_duplicates(inplace=True)

# %% [markdown]
# Check that the row count reflects the drops.

# %%
final_df.shape
# Out:
# (16816, 13)

# %% [markdown]
# Check the value counts for the `department` column.

# %%
final_df['department'].value_counts(normalize=True, dropna=False)
# Out:
# Clothing, Shoes & Jewelry     0.765699
# 0                             0.114355
# unknown category              0.069041
# Sports & Outdoors             0.033837
# Toys & Games                  0.004579
# Health & Household            0.002973
# Home & Kitchen                0.001725
# Arts, Crafts & Sewing         0.001725
# Electronics                   0.001665
# Tools & Home Improvement      0.001130
# Beauty & Personal Care        0.001070
# Automotive                    0.000654
# Baby Products                 0.000476
# Office Products               0.000357
# Cell Phones & Accessories     0.000297
# Software                      0.000178
# Industrial & Scientific       0.000119
# Appliances                    0.000059
# Purchase Circles              0.000059
# Name: department, dtype: float64

# %% [markdown]
# Drop the rows that have unknown category or 0 in `department` column.

# %%
final_df = final_df[(final_df['department'] != 'unknown category') & (final_df['department'] != 0)]

# %% [markdown]
# Check that the shape reflects dropped rows.

# %%
final_df.shape
# Out:
# (13732, 13)

# %% [markdown]
# Save to final everything to csv.

# %%
# final_df.to_csv('data/final_df.csv')
