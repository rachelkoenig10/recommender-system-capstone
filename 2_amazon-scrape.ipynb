# %% [markdown]
# ## Web Scraping with Selenium
# _Author: Rachel Koenig_
# _____

# %% [markdown]
# You may need to install selenium if you haven't already.  Just uncomment the below cell to do so.

# %%
#pip install selenium

# %% [markdown]
# Imports

# %%
import json
import pandas as pd
import gzip

from bs4 import BeautifulSoup
from requests import get
import requests

from selenium import webdriver
import time

from random import randint
from time import sleep

# %% [markdown]
# The below code is needed to unzip and read in a json zip file.
# Dataset is not shared on github because it is larger than the allowed max size, but can be downloaded here by clicking '5-core' next Clothing, Shoes and Jewelry.  Then change the getDF file path to wherever you save the download.
# http://jmcauley.ucsd.edu/data/amazon/index.html

# %%
def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

df = getDF('data/reviews_Clothing_Shoes_and_Jewelry_5.json.gz')

# %%
# Check the first 60 rows 
df.head(60)
# Out:
#         reviewerID        asin  \
# 0   A1KLRMWW2FWPL4  0000031887
# 1   A2G5TCU2WDFZ65  0000031887
# 2   A1RLQXYNCMWRWN  0000031887
# 3    A8U3FAMSJVHS5  0000031887
# 4   A3GEOILWLK86XM  0000031887
# 5    A27UF1MSF3DB2  0000031887
# 6   A16GFPNVF4Y816  0000031887
# 7   A2M2APVYIB2U6K  0000031887
# 8   A1NJ71X3YPQNQ9  0000031887
# 9    A3EERSWHAI6SO  0000031887
# 10   AX1QE6IR7CHXM  0000031887
# 11  A2A2WZYLU528RO  0000031887
# 12  A391EXIT5TFP72  0000031887
# 13  A34ATJR9KFIXL9  0000031887
# 14   AJ6B83I4YJHYW  0000031887
# 15  A26A4KKLAVTMCC  0000031887
# 16  A1MXJVYXE2QU6H  0000031887
# 17  A2XJ13PIXVJFJH  0000031887
# 18  A287XY94U7JDM8  0000031887
# 19  A1JR9KKF6UKUWW  0000031887
# 20  A2SX7X8QGQVCJU  0000031887
# 21  A2Q6UWR5PBHTJS  0000031887
# 22   AJZPHJR944IBB  0000031887
# 23  A2WNN1DQVL4LH5  0123456479
# 24  A1ZPOCG2ST2CY3  0123456479
# 25  A1WDJIFL2F4QJA  0123456479
# 26  A3RB1JA72Z0TUN  0123456479
# 27  A1JC50F14SLAEV  0123456479
# 28   A8WD29DKN8ZC3  0123456479
# 29  A1F7YU6O5RU432  1608299953
# 30  A3INPLAFCMRI3I  1608299953
# 31  A3NHUQ33CFH3VM  1608299953
# 32  A253TILLU81VZK  1608299953
# 33  A28QH3KX709FFQ  1608299953
# 34  A1R377IPZOKLMM  1608299953
# 35  A3U6J0DLLDEWM2  1608299953
# 36  A1ZU55TM45Y2R8  1608299953
# 37   A1NIGUK4M2ST8  1608299953
# 38   AQY5XBYSENNZQ  1608299953
# 39  A1GNYV0RA0EQSS  1608299953
# 40  A3D5B2CBFNJB0K  1608299953
# 41  A35V32HZEGZH04  1608299953
# 42  A31ICLWQ9CSHRS  1617160377
# 43  A3I1BJIFFM4S21  1617160377
# 44  A216NSW58Q3SCJ  1617160377
# 45  A25C2M3QF9G7OQ  1617160377
# 46  A2BN9DIBP9A0XG  1617160377
# 47   AY3D7DG5L5WCK  1617160377
# 48   AOEDWQLH2WKKW  1617160377
# 49   AN81JUYW2SL24  1617160377
# 50  A20FK68BUB1IVA  1617160377
# 51   AZAC8O310IK4E  1617160377
# 52  A3U6J0DLLDEWM2  1617160377
# 53  A2JCJJNY43QQIV  1617160377
# 54  A2VH0UT5EQFB6P  1617160377
# 55  A18S2VGUH9SCV5  1617160377
# 56  A379DLIAF0MFM5  1617160377
# 57  A3MHGA6BJJ7P27  1617160377
# 58  A1059SSXUZZS1S  B00001W0KA
# 59  A2VNCKMXMHN9E8  B00001W0KA
#
#                                         reviewerName     helpful  \
# 0                        Amazon Customer "cameramom"      [0, 0]
# 1                                    Amazon Customer      [0, 0]
# 2                                             Carola      [0, 0]
# 3                                            Caromcg      [0, 0]
# 4                                                 CJ      [0, 0]
# 5                                     C-Lo "Cynthia"      [0, 0]
# 6                                       design maven      [0, 0]
# 7                                           Jamie P.      [0, 0]
# 8                                            JBerger      [0, 0]
# 9        Jeffrey Hollingshead "Jillian hollingshead"      [7, 8]
# 10                                                JJ      [0, 0]
# 11                                      Julie Gayler      [0, 0]
# 12                                     Lisbeth Starr      [0, 0]
# 13                                            Maudy1      [1, 1]
# 14                                          M. Davis      [0, 0]
# 15                                         Moonlight      [0, 0]
# 16                         Mother Goose "WI Grandma"      [0, 0]
# 17                               Myra MLH "Myra MLH"      [0, 0]
# 18                                           Natasha      [0, 0]
# 19                                     Queens Meadow      [0, 0]
# 20                                           Shannon      [0, 0]
# 21                                   Sylvia "Sylvia"      [0, 0]
# 22                                V's Mommy in Mass.      [1, 2]
# 23                                          Caddycat      [1, 1]
# 24                                       Deedee King      [0, 1]
# 25                                             Eddie      [1, 2]
# 26                                          Elena M.      [0, 0]
# 27                                              Mada      [0, 0]
# 28                                         Shopper22      [0, 0]
# 29                                    Angela Streiff      [0, 0]
# 30                                            Cheryl  [201, 205]
# 31                                      Citizen John      [5, 6]
# 32                                       D. Connelly    [11, 13]
# 33                               Don Quixote "Don Q"    [24, 31]
# 34                        Gina B. "It's a dry heat!"      [0, 3]
# 35                                      Jason Stokes    [62, 66]
# 36                                        J. Haggard    [31, 34]
# 37                                                mk      [7, 9]
# 38                                         Quickbeam      [5, 6]
# 39                              Sl Judge "gatormomz"      [2, 3]
# 40                                             ut158    [11, 12]
# 41                                   W. Easley "Opa"      [2, 5]
# 42                                        Al Swanson      [0, 0]
# 43                                   Atomicwasteland      [8, 8]
# 44                             ccincalif "ccincalif"      [0, 0]
# 45                                            Comdet      [1, 1]
# 46                                          D. Vance      [0, 0]
# 47                          Edward Walker "ednpatty"      [0, 1]
# 48                                 E. J Tastad "ejt"      [1, 1]
# 49                                    Gearhead Mania      [0, 0]
# 50                                      Happy Reader      [0, 1]
# 51                                          Hoppaguy      [2, 2]
# 52                                      Jason Stokes      [0, 0]
# 53                                         Katy Lake      [6, 6]
# 54                                        Loveguitar      [3, 3]
# 55                                   Margaux Paschke    [37, 41]
# 56  Mr. Deeds "Opportunity is limited only by ima...      [7, 7]
# 57               W. T. Hoffman "artist and musician"     [9, 10]
# 58                                            Cassie      [0, 0]
# 59                                               EAD      [0, 0]
#
#                                            reviewText  overall  \
# 0   This is a great tutu and at a really great pri...      5.0
# 1   I bought this for my 4 yr old daughter for dan...      5.0
# 2   What can I say... my daughters have it in oran...      5.0
# 3   We bought several tutus at once, and they are ...      5.0
# 4   Thank you Halo Heaven great product for Little...      5.0
# 5   I received this today and I'm not a fan of it ...      4.0
# 6   Bought this as a backup to the regular ballet ...      5.0
# 7   Great tutu for a great price. It isn't a &#34;...      5.0
# 8   My daughter liked this, and it with her costum...      4.0
# 9   For what I paid for two tutus is unbeatable an...      5.0
# 10  Wonder my niece wears it every single day, yel...      5.0
# 11  My daughter has worn this skirt almost every d...      5.0
# 12  Purchased this tutu for my granddaughter's fir...      5.0
# 13  Full and well stitched.  This tutu is a beauti...      5.0
# 14  This was a gift for a two year old and a five ...      5.0
# 15  My 3yr old loved this tutu skirt in pink! Was ...      3.0
# 16  Perfect for my budding grand daughter ballerin...      5.0
# 17  Never GOT this item - but gave a 1 STAR becaus...      1.0
# 18  Nice and puffy tutu skirt. I would recommend t...      5.0
# 19  Bought this for my niece as part of her fairy ...      5.0
# 20  My 4 year old daughter always wants to play dr...      5.0
# 21  Our granddaughters are all very girlie, so whe...      5.0
# 22  Prompt delivery, and it is exactly as describe...      4.0
# 23  The minute I saw this my heart skipped a beat....      5.0
# 24  Love this Jewelry Box  so well put together ho...      5.0
# 25  This products is great for anyone with a lot o...      5.0
# 26  I already own this particular Shining Image je...      3.0
# 27  I wanted to have the title summarize my though...      3.0
# 28  Really nice box, a bit cheaply made. It is mad...      4.0
# 29  Since learning a language from software is not...      5.0
# 30  The product itself is five stars, however the ...      4.0
# 31  The first question was which computers to inst...      4.0
# 32  Okay, I admit it. I'm one of the millions of A...      5.0
# 33  I bought this product a little over a year ago...      1.0
# 34  I really enjoy the Rosetta Stone software; it'...      5.0
# 35  I've never had french, learned french, or know...      5.0
# 36  La Femme Boit...... I think that means the gir...      4.0
# 37  The Rosetta Stone process gets you involve thr...      4.0
# 38  I have had this product for a while to evaluat...      4.0
# 39  Bring French to life!If your child is taking t...      5.0
# 40  I got this product for my sister who enjoyed t...      5.0
# 41  .When in the military,  I was stationed in Eur...      5.0
# 42  If you really need to learn a new language, an...      5.0
# 43  Never having studied Italian before, and never...      4.0
# 44  Although I haven't kept up with the lessons as...      5.0
# 45  I've always found learning a new language to b...      5.0
# 46  I was thrilled to get the Rosetta Stone and be...      5.0
# 47  I love Rosetta Stone it is easy to use in a fe...      5.0
# 48  Install Machine:Intel iMac 3.06 GHz Intel Core...      5.0
# 49  Rosetta Stone Italiano Level 1Rosetta Stone It...      4.0
# 50  I was prepared to be disappointed with Rosetta...      5.0
# 51  I actually have used the Rosetta Stone Spanish...      5.0
# 52  I've been using this for a few weeks. Previous...      4.0
# 53  I have to admit, I was more impressed by Roset...      4.0
# 54  I've had the opportunity to review several Ros...      4.0
# 55  I wanted a refresher course in Italian so I or...      4.0
# 56  I got Rosetta Stone Italian Level 1 a few mont...      5.0
# 57  ROSETTA STONE is famous for teaching language ...      5.0
# 58  We got this costume for my son to wear to Disn...      4.0
# 59  Purchased this costume (size 3T-4T) and it's a...      5.0
#
#                                               summary  unixReviewTime  \
# 0                       Great tutu-  not cheaply made      1297468800
# 1                                         Very Cute!!      1358553600
# 2                            I have buy more than one      1357257600
# 3                                    Adorable, Sturdy      1398556800
# 4                             Grammy's Angels Love it      1394841600
# 5                                             It's ok      1396224000
# 6          Great for dress-up and for ballet practice      1399075200
# 7                                         Great value      1356220800
# 8                                                Good      1384041600
# 9                      WOW !! ..is all I have to say!      1349568000
# 10                      Wonderful and great shipping.      1388620800
# 11                                 Excellent quality!      1391040000
# 12                                    Wonderful tutu!      1321056000
# 13                                         Great Tutu      1361664000
# 14                       Great tutu for little girls!      1372636800
# 15                              Came apart in 2weeks!      1395273600
# 16                                           So cute!      1367020800
# 17                                   Never GOT IT....      1399852800
# 18                                         Nice skirt      1387843200
# 19                     must have for a fairy princess      1359504000
# 20                               My daughter loved it      1351036800
# 21                                             Sassy!      1358553600
# 22                  Practically Perfect in every way!      1365552000
# 23                               Breathtaking 5 Stars      1383782400
# 24                                          VERY NICE      1390089600
# 25                       Amazing so many compartments      1348444800
# 26                              Arrived with a defect      1387411200
# 27                Nice Size But Drawers Are A Concern      1399852800
# 28                                  Great jewelry box      1388102400
# 29  Suggest getting this 1 level at a time, so you...      1365465600
# 30                              4 stars BUT beware...      1322956800
# 31                               Intense way to learn      1285027200
# 32  Helped me actually get an A in a foreign langu...      1308182400
# 33          DO NOT BUY IF YOU EVER WANT TO RESELL IT.      1348185600
# 34               Rosetta Stone software is fun to use      1284768000
# 35  Great way to obtain functional conversation in...      1287446400
# 36  Great software, not so fun to install, and hea...      1282694400
# 37            A Neat System of Learning, A BIt Pricey      1305676800
# 38  Really nice refresher, unable to get microphon...      1305763200
# 39            Rosetta Stone - Excellent way to learn!      1284163200
# 40                                  Fun and effective      1290038400
# 41                                 Becoming Bilingual      1328918400
# 42          A real improvement over the last version!      1305936000
# 43                Nice system, but way too expensive.      1340150400
# 44  Better than any other method/software I've tried.      1368403200
# 45                    A good way to get your feet wet      1299888000
# 46                                        Great tool!      1329696000
# 47                                        Easy to use      1365120000
# 48                            Makes Learning a Breeze      1298505600
# 49  Easy to use, but the phrases need to be more u...      1299196800
# 50                    Voice Recognition Really Works!      1318464000
# 51                      Best way to learn a language!      1299024000
# 52                          Helped my limited italian      1299715200
# 53                       Nice start to a new language      1337126400
# 54                      Rosetta Stone Italian Level 1      1303171200
# 55  a great way to learn italian if you can afford it      1298419200
# 56   Made our vacation in Rome much easier - and fun!      1365120000
# 57             The EXASPERATION of SPEACH RECOGNITION      1309305600
# 58                   Great Costume, Awkward To Put On      1383696000
# 59                   Perfectly fits my 2 year-old :-)      1383091200
#
#      reviewTime
# 0   02 12, 2011
# 1   01 19, 2013
# 2    01 4, 2013
# 3   04 27, 2014
# 4   03 15, 2014
# 5   03 31, 2014
# 6    05 3, 2014
# 7   12 23, 2012
# 8   11 10, 2013
# 9    10 7, 2012
# 10   01 2, 2014
# 11  01 30, 2014
# 12  11 12, 2011
# 13  02 24, 2013
# 14   07 1, 2013
# 15  03 20, 2014
# 16  04 27, 2013
# 17  05 12, 2014
# 18  12 24, 2013
# 19  01 30, 2013
# 20  10 24, 2012
# 21  01 19, 2013
# 22  04 10, 2013
# 23   11 7, 2013
# 24  01 19, 2014
# 25  09 24, 2012
# 26  12 19, 2013
# 27  05 12, 2014
# 28  12 27, 2013
# 29   04 9, 2013
# 30   12 4, 2011
# 31  09 21, 2010
# 32  06 16, 2011
# 33  09 21, 2012
# 34  09 18, 2010
# 35  10 19, 2010
# 36  08 25, 2010
# 37  05 18, 2011
# 38  05 19, 2011
# 39  09 11, 2010
# 40  11 18, 2010
# 41  02 11, 2012
# 42  05 21, 2011
# 43  06 20, 2012
# 44  05 13, 2013
# 45  03 12, 2011
# 46  02 20, 2012
# 47   04 5, 2013
# 48  02 24, 2011
# 49   03 4, 2011
# 50  10 13, 2011
# 51   03 2, 2011
# 52  03 10, 2011
# 53  05 16, 2012
# 54  04 19, 2011
# 55  02 23, 2011
# 56   04 5, 2013
# 57  06 29, 2011
# 58   11 6, 2013
# 59  10 30, 2013

# %% [markdown]
# ### EDA

# %%
#Check size of dataset: 278,677 rows & 9 columns. 
df.shape
# Out:
# (278677, 9)

# %%
# Check columns names 
df.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewerName', 'helpful', 'reviewText',
#        'overall', 'summary', 'unixReviewTime', 'reviewTime'],
#       dtype='object')

# %%
# Check out an individual product ID
df[df['asin'] == 'B00971NLBS']
# Out:
#             reviewerID        asin                         reviewerName  \
# 224886  A1J4GHI1VRLCX9  B00971NLBS                                 Alya
# 224887  A21UXFFQGQS4YJ  B00971NLBS                 Anne Harris "Lady H"
# 224888  A22Z5LSEIPN8DU  B00971NLBS                              Ashleyy
# 224889  A3SP43WB89B2UE  B00971NLBS                 cecilafayette "ceci"
# 224890  A1Q3MDPIS017JE  B00971NLBS                                Kay Z
# 224891  A1BCJXOINBPB38  B00971NLBS  lascrucesgirl "Growing boy's momma"
# 224892  A1AFORE8L2LGGW  B00971NLBS                        mandamommyof3
# 224893  A22E4B018G6NX7  B00971NLBS                             RDeering
#
#        helpful                                         reviewText  overall  \
# 224886  [1, 1]  I will be purchasing more of this brand of shi...      5.0
# 224887  [0, 0]  I found it to be a little roomy but it will be...      5.0
# 224888  [0, 0]  I ordered this shirt in a light blue, size two...      2.0
# 224889  [0, 0]  This shirt fits well, looks nice, and is a gre...      4.0
# 224890  [0, 0]  The material is a little thin, but that was ex...      4.0
# 224891  [3, 4]  I did not use the tie for my son. It was dress...      5.0
# 224892  [5, 5]  This is adorable!  I would buy more if the tie...      4.0
# 224893  [0, 0]  Nice little shirt I couldn't find elsewhere th...      5.0
#
#                              summary  unixReviewTime   reviewTime
# 224886                       Classic      1374624000  07 24, 2013
# 224887              nice dress shirt      1393545600  02 28, 2014
# 224888      Wrong color, wrong size.      1372291200  06 27, 2013
# 224889      Great Little Basic Shirt      1388102400  12 27, 2013
# 224890         Good fit, little thin      1400284800  05 17, 2014
# 224891  Nicely made and looks sharp.      1360627200  02 12, 2013
# 224892              Tie is too short      1356652800  12 28, 2012
# 224893                can't complain      1388966400   01 6, 2014

# %%
#Check how many unique items are in the data 
len(df['asin'].unique())
# Out:
# 23033

# %%
#Created a non-repeating list of product ID #s with the intent of looping through them in the url to scrape. 
asin_set = set(df['asin'])
asin_set = list(asin_set)

# %%
#Sort the list in alphabetical order so that it is the same everytime 
asin_set.sort()

# %%
# Look at the first 10 objects in the list 
asin_set[:10]
# Out:
# ['0000031887',
#  '0123456479',
#  '1608299953',
#  '1617160377',
#  'B00001W0KA',
#  'B00001WRHJ',
#  'B00004SR8W',
#  'B00004SR8Z',
#  'B00004SR9P',
#  'B00004U1J2']

# %%
#Check how many unique users are in the data. 
len(df['reviewerID'].unique())
# Out:
# 39387

# %% [markdown]
# ### Scrape additional data using Selenium

# %%
# Instantiate a webdriver 
driver = webdriver.Chrome(executable_path="../chromedriver/macos/chromedriver")

# %% [markdown]
# NOTE: Below scraper is set to only loop through the first 20 items in the asin list, but can be changed to any amount.

# %%
# Set start time and print it on the first row 
t1 = time.time()  
print(t1)

# Instantiate an empty list 
list_of_dicts = []  

# Loop through every item in the asin list. 
for i in asin_set[:20]:  
    
    # Print the urls at the beginning of each loop 
    print(f'https://www.amazon.com/gp/product/{i}')
    
    # Send webdriver to the next url in the loop
    driver.get(f'https://www.amazon.com/gp/product/{i}')
    
    # Instantiate BeautifulSoup web scraper 
    soup = BeautifulSoup(driver.page_source, 'lxml') 
    
    # Create an empty dictionary 
    product_info = {}
    
    # Try to locate these tags and save the information as a key-value pair in the product_info dict.
    try:
        # Save product ID # so I can identify which product the scrape belongs to 
        product_info['asin'] = i
        
        # Look for product title 
        product_info['name'] = soup.find('span', {'id':'productTitle'}).text.strip()

        # Look for product description
        product_info['description'] = soup.find('ul', {'class':'a-unordered-list a-vertical a-spacing-none'}).text.strip()
        
        # Look for product categories list 
        product_info['category'] = soup.find('ul', {'class': 'a-unordered-list a-horizontal a-size-small'}).text.strip()
        
        # Look for product size 
        product_info['size'] = soup.find('div', {'id': 'variation_size_name'})
        
        # Look for additional product details as a catch all 
        product_info['details'] = soup.find_all('td', {'class': 'a-span7 a-size-base'})
        
        # There were 3 possibile tags to get color info, whichever one works will be the end of the loop
        if soup.find('div', {'id': 'variation_color_name'}):
            product_info['color'] = soup.find('div', {'id': 'variation_color_name'})
            list_of_dicts.append(product_info)  # Append scrape to dictionary 
        
        elif soup.find_all('span', {'class': 'selection'}):
            product_info['color'] = soup.find_all('span', {'class': 'selection'})
            list_of_dicts.append(product_info)
            
        elif soup.find_all('div', {'class': 'a-row a-spacing-micro'}):
            product_info['color'] = soup.find_all('div', {'class': 'a-row a-spacing-micro'})
            list_of_dicts.append(product_info)
        
        # If none existed, label as color unavailable 
        else:
            product_info['color'] = 'unavailable'
            list_of_dicts.append(product_info) # Append scrape to dictionary 
    
    # If product id in the url throws an error, rather than breaking the code, return info unknown.
    except:
        product_info['asin'] = i
        
        product_info['name'] = 'unknown product name'

        product_info['description'] = 'unknown details'
        
        product_info['category'] = 'unknown category'
        
        product_info['color'] = 'unknown color' 
        
        list_of_dicts.append(product_info)  # Append scrape to dictionary 
        print(len(list_of_dicts))   # If there is an error page, print the current length of the scrapes.
        
    # Sleep 1 or 2 seconds in bewteen scrapes so Amazon doesn't think we're a robot.
    sleep(randint(1,2))
    

# Print final time subtract start time to figure out how long the scraper took to run. 
print(time.time() - t1)
# Out:
# 1566771396.386451
# https://www.amazon.com/gp/product/0000031887
# https://www.amazon.com/gp/product/0123456479
# https://www.amazon.com/gp/product/1608299953
# https://www.amazon.com/gp/product/1617160377
# https://www.amazon.com/gp/product/B00001W0KA
# https://www.amazon.com/gp/product/B00001WRHJ
# https://www.amazon.com/gp/product/B00004SR8W
# https://www.amazon.com/gp/product/B00004SR8Z
# https://www.amazon.com/gp/product/B00004SR9P
# https://www.amazon.com/gp/product/B00004U1J2
# https://www.amazon.com/gp/product/B000051SEN
# https://www.amazon.com/gp/product/B000051SEP
# https://www.amazon.com/gp/product/B00005JHKE
# https://www.amazon.com/gp/product/B00005JSBK
# https://www.amazon.com/gp/product/B00005KJXN
# https://www.amazon.com/gp/product/B00005TQI7
# 16
# https://www.amazon.com/gp/product/B0000643Q8
# https://www.amazon.com/gp/product/B000067R84
# https://www.amazon.com/gp/product/B00006I551
# https://www.amazon.com/gp/product/B00006XXGO
# 79.44853019714355

# %% [markdown]
# Check the length of the scrape

# %%
len(list_of_dicts)
# Out:
# 20

# %% [markdown]
# Check the number of "unknown" rows to make sure it's low.

# %%
pd.DataFrame(list_of_dicts)['name'].value_counts().head()
# Out:
# SUUNTO X-Lander Wrist-Top Computer Watch with Altimeter, Barometer, Compass, and Chronograph    2
# Spider-Man Child Standard Costume                                                               1
# Woody Deluxe Child - Size: Child S(4-6)                                                         1
# Disney Buzz Lightyear Toy Story 4 Boys' Inflatable Jet Pack                                     1
# Learn Italian: Rosetta Stone Italian - Level 1                                                  1
# Name: name, dtype: int64

# %% [markdown]
# Save first 8000 scrapes to a DataFrame and then to a csv

# %%
# product8000 = pd.DataFrame(list_of_dicts)

# product8000.to_csv('product8000.csv')

# %% [markdown]
# Saved next 534 scrapes to a DataFrame and then to a csv

# %%
# product8534 = pd.DataFrame(list_of_dicts)

# product8534.to_csv('data/product8534')

# %% [markdown]
# Saved next 6000 scrapes to a DataFrame and then to a csv

# %%
# product14000 = pd.DataFrame(list_of_dicts)

# product14000.to_csv('product14000.csv')

# %% [markdown]
# Saved another 6000 scrapes to a DataFrame and then to a csv

# %%
# product20000 = pd.DataFrame(list_of_dicts)

# product20000.to_csv('product20000.csv')

# %% [markdown]
# Saved next 1180 scrapes to a DataFrame and then to a csv

# %%
# product21180 = pd.DataFrame(list_of_dicts)

# product21180.to_csv('product21180.csv')

# %% [markdown]
# Saved last section of scrapes to a DataFrame and then to a csv

# %%
# product23033 = pd.DataFrame(list_of_dicts)

# product23033.to_csv('product23033.csv')

# %% [markdown]
# Many of the above scrapes were blocked by an anti-robot page so i'll need to go through and check for unavailable rows and make a new list of asins to rescrape.

# %%
# Function to remove html
def remove_html(text):
    try:
        soup = BeautifulSoup(text, 'lxml')
        html_free = soup.get_text(strip=True)
        return html_free
    except:
        return "missing"

# %%
# Function to clean the DataFrame
def EDA(df):
    # Remove html and strip off brackets and 'Color:' from color column
    df['color'] = df['color'].apply(lambda x: remove_html(x)).str.replace(']', '').str.replace('[', '').str.replace('Color:', '')
    
    # Replace escape characters and white space in Category column 
    df['category'] = df['category'].str.replace('\n', '').str.replace('  ', '')
    
    # Split Category column on the '›' symbol, up to 6 times and return them in a new df where each split is a new column 
    category = df['category'].str.split("›", n=6, expand=True)
    
    # Rename each category split column and add it onto the original df
    df['department'] = category[0]
    df['demographic'] = category[1]
    df['division'] = category[2]
    df['category'] = category[3]
    df['subcategory'] = category[4]
    df['type'] = category[5]
    df['detail_type'] = category[6]
    
    # Remove special characters from the description column 
    df['description'] = df['description'].str.replace('\t', '').str.replace('\n', '')
    
    # Remove html and strip off brackets from details column
    df['details'] = df['details'].apply(lambda x: remove_html(x)).str.replace(']', '').str.replace('[', '')
   
    #Remove html and cut off 'Size:' from the size column 
    df['size'] = df['size'].apply(lambda x: remove_html(x)).str.replace('Size:', '')
    
    return df.head()

# %%
product8000 = pd.read_csv('scrapes/product8000.csv')

# %%
product20000 = pd.read_csv('scrapes/product20000.csv')

# %%
product21180 = pd.read_csv('scrapes/product21180.csv')

# %%
product23033 = pd.read_csv('scrapes/product23033.csv')

# %%
#A list of DataFrames to be concatonated
dataframes = [product8000, product20000, product21180, product23033]

# Concat all 4 DataFrames into one, along the row axis.
total_product = pd.concat(dataframes, axis=0)

# %%
total_product.shape
# Out:
# (17033, 8)

# %%
EDA(total_product)
# Out:
#    Unnamed: 0        asin                      category           color  \
# 0           0  0000031887                        Dance      unavailable
# 1           1  0123456479   Jewelry Boxes & Organizers      unavailable
# 2           2  1608299953                          None     unavailable
# 3           3  1617160377                          None     unavailable
# 4           4  B00001W0KA                          None  Buzz Lightyear
#
#                                          description details  \
# 0  This fits your .     Make sure this fitsby ent...
# 1  This fits your .     Make sure this fitsby ent...
# 2  Access for up to 5 family members Download act...
# 3  Access for up to 5 family members Download act...
# 4  Lead Free Child (4-6 & 7-8) Includes: Bodysuit...
#
#                                                 name  \
# 0   Mystiqueshapes Girls Ballet Tutu Neon Lime Green
# 1  SHINING IMAGE HUGE PINK LEATHER JEWELRY BOX / ...
# 2       Learn French: Rosetta Stone French - Level 1
# 3     Learn Italian: Rosetta Stone Italian - Level 1
# 4      Buzz Lightyear Boy's Deluxe Toy Story Costume
#
#                                                 size  \
# 0                                            missing
# 1                                            missing
# 2                                            missing
# 3                                            missing
# 4  SelectM(3T-4T)3T-4TSmall (4-6)Medium (7-8)Medi...
#
#                    department                          demographic  \
# 0          Sports & Outdoors                     Sports & Fitness
# 1  Clothing, Shoes & Jewelry    Shoe, Jewelry & Watch Accessories
# 2                   Software                Education & Reference
# 3                   Software                Education & Reference
# 4               Toys & Games              Dress Up & Pretend Play
#
#                 division    subcategory     type detail_type
# 0          Other Sports       Clothing    Girls       Skirts
# 1   Jewelry Accessories   Jewelry Boxes     None        None
# 2              Languages           None     None        None
# 3              Languages           None     None        None
# 4               Costumes           None     None        None

# %% [markdown]
# Create a dataframe for only rows that came back unknown.

# %%
redo_df = total_product[total_product['department'] == 'unknown category']

# %%
# Check the shape 
redo_df.shape
# Out:
# (12009, 14)

# %%
# Check for nulls 
redo_df.isnull().sum()
# Out:
# Unnamed: 0         0
# asin               0
# category       12009
# color              0
# description        0
# details            0
# name               0
# size               0
# department         0
# demographic    12009
# division       12009
# subcategory    12009
# type           12009
# detail_type    12009
# dtype: int64

# %%
redo_list = list(redo_df['asin'])
redo_list[:10]
# Out:
# ['B00005TQI7',
#  'B0000722HK',
#  'B00007GD9I',
#  'B0000864CZ',
#  'B0000866JI',
#  'B0000867AN',
#  'B0000867GG',
#  'B0000867ON',
#  'B00008695M',
#  'B0000869QI']

# %%
len(redo_list)
# Out:
# 12009

# %% [markdown]
# Use `redo_list` to run another round of scrapes in case some were blocked by anit-robot pages on the first try.

# %% [markdown]
# Save redo scrapes to a DataFrame and then all rows that are not unknown to a csv

# %%
# redo2000 = pd.DataFrame(list_of_dicts)

#(redo2000[redo2000['department'] != 'unknown category']).to_csv('data/redo1.csv')

# %%
#redo6000 = pd.DataFrame(list_of_dicts)

# (redo6000[redo6000['department'] != 'unknown category']).to_csv('data/redo2.csv')

# %%
#redo6455 = pd.DataFrame(list_of_dicts)

# (redo6455[redo6455['department'] != 'unknown category']).to_csv('data/redo3.csv')

# %%
# Save rescrape to a DataFrame 
# redo8528 = pd.DataFrame(list_of_dicts)

# Save the cleaned data to a csv
# redo8528.to_csv('redo_list1.csv')

# Read in the cleaned data & check shape
redo8528 = pd.read_csv('scrapes/redo_list1.csv', index_col=[0])
redo8528.shape
# Out:
# (2073, 13)

# %%
# Use funtion to clean rescrape 
# EDA(redo8528)

# %%
#Check value_counts of category column to see if there are any noticable trends.
redo8528['category'].value_counts(dropna=False).head(10)
# Out:
# NaN                           1146
#  Athletic                       98
#  Sandals                        70
#  Lingerie, Sleep & Lounge       55
# Wrist Watches                   39
#  Boots                          35
# Pumps                           30
# Flats                           30
#  Earrings                       29
#  Tops, Tees & Blouses           26
# Name: category, dtype: int64

# %%
# Check how many product names were collected  
(redo8528[redo8528['name'] != 'unknown product name']).shape
# Out:
# (950, 13)

# %%
# Save only rows that have department values to a new csv to be joined on to the clean data in a different notebook.
# (redo8528[redo8528['department'] != 'unknown category']).to_csv('data/redo4.csv')

# %%
# Check if number of categories collected matches names
(redo8528[redo8528['department'] != 'unknown category']).shape
# Out:
# (950, 13)

# %%
# Saved rescrape 
#redo10000 = pd.DataFrame(list_of_dicts)

# %%
# Used function to clean rescraped data
# EDA(redo10000)

# %%
# Save known column names to a csv
# (redo10000[redo10000['name'] != 'unknown product name']).to_csv('data/redo5.csv')

# %%
# Save clean rescraped data to a csv
#redo10000.to_csv('redo_list2.csv')

redo10000 = pd.read_csv('scrapes/redo_list2.csv', index_col=[0])
redo10000.head()
# Out:
#          asin       category        color  \
# 0  B009L4OGDS      Earrings   unavailable
# 1  B009L5081Q       Novelty   unavailable
# 2  B009L53QXI         Boots       missing
# 3  B009L5YU7O  Shoulder Bags      missing
# 4  B009LB8CX6        Active       missing
#
#                                          description  details  \
# 0  6mm Crystal Ball Stud Earrings Plain Post and ...  missing
# 1  Size: One size only (small) Total Length: Abou...  missing
# 2  Synthetic Made in USA or Imported Synthetic so...  missing
# 3  Leathette Imported fabric lining Snap closure ...  missing
# 4  Made in USA or Imported Merino wool blend Fibe...  missing
#
#                                                 name     size  \
# 0    Sterling Silver Pink Crystal Ball Stud Earrings  missing
# 1  Ninimour- Fashion Trendy Women's Stretchy Legg...  missing
# 2  Dark Tan Faux Leather Bold Red Back Zipper Buc...  missing
# 3  MG Collection Yelena Top Handle Soft Hobo Shou...  missing
# 4  Kirkland Signature Outdoor Trail Sock Merino W...  missing
#
#                    department       demographic              division  \
# 0  Clothing, Shoes & Jewelry             Women               Jewelry
# 1  Clothing, Shoes & Jewelry    Novelty & More              Clothing
# 2  Clothing, Shoes & Jewelry             Women                 Shoes
# 3  Clothing, Shoes & Jewelry             Women    Handbags & Wallets
# 4  Clothing, Shoes & Jewelry             Women              Clothing
#
#       subcategory      type detail_type
# 0            Stud       NaN         NaN
# 1          Women   Leggings         NaN
# 2        Mid-Calf       NaN         NaN
# 3             NaN       NaN         NaN
# 4  Athletic Socks       NaN         NaN

# %%
(redo10000[redo10000['name'] == 'unknown product name']).head()
# Out:
#             asin category          color      description  details  \
# 8     B009LEFPAQ      NaN  unknown color  unknown details  missing
# 10    B009LEFR4A      NaN  unknown color  unknown details  missing
# 11    B009LEFS26      NaN  unknown color  unknown details  missing
# 12    B009LEG2EO      NaN  unknown color  unknown details  missing
# 13    B009LEG3XO      NaN  unknown color  unknown details  missing
# 16    B009LM7BWS      NaN  unknown color  unknown details  missing
# 17    B009LNATJY      NaN  unknown color  unknown details  missing
# 22    B009LZTK10      NaN  unknown color  unknown details  missing
# 24    B009M8UF38      NaN  unknown color  unknown details  missing
# 28    B009MAW0A2      NaN  unknown color  unknown details  missing
# 30    B009MB9F4K      NaN  unknown color  unknown details  missing
# 32    B009MDMYJG      NaN  unknown color  unknown details  missing
# 37    B009MS2AT0      NaN  unknown color  unknown details  missing
# 39    B009N0CSXU      NaN  unknown color  unknown details  missing
# 43    B009NB8BU8      NaN  unknown color  unknown details  missing
# 52    B009NONIHG      NaN  unknown color  unknown details  missing
# 56    B009NQCBOK      NaN  unknown color  unknown details  missing
# 58    B009NQUE9E      NaN  unknown color  unknown details  missing
# 59    B009NQUV2E      NaN  unknown color  unknown details  missing
# 67    B009O9YEPA      NaN  unknown color  unknown details  missing
# 69    B009OAIG6W      NaN  unknown color  unknown details  missing
# 72    B009OJEPK4      NaN  unknown color  unknown details  missing
# 76    B009OKPR96      NaN  unknown color  unknown details  missing
# 77    B009OVPGNW      NaN  unknown color  unknown details  missing
# 78    B009OWV0F4      NaN  unknown color  unknown details  missing
# 81    B009OZNWZW      NaN  unknown color  unknown details  missing
# 83    B009P00AJM      NaN  unknown color  unknown details  missing
# 85    B009P1KGGI      NaN  unknown color  unknown details  missing
# 89    B009P5G06Y      NaN  unknown color  unknown details  missing
# 92    B009P82H8Q      NaN  unknown color  unknown details  missing
# ...          ...      ...            ...              ...      ...
# 1436  B00B7ETWNO      NaN  unknown color  unknown details  missing
# 1437  B00B7F3LIK      NaN  unknown color  unknown details  missing
# 1439  B00B7HQIA6      NaN  unknown color  unknown details  missing
# 1440  B00B7M9IRQ      NaN  unknown color  unknown details  missing
# 1441  B00B7MELBE      NaN  unknown color  unknown details  missing
# 1442  B00B7MG47S      NaN  unknown color  unknown details  missing
# 1443  B00B7MQF18      NaN  unknown color  unknown details  missing
# 1444  B00B7NHZK2      NaN  unknown color  unknown details  missing
# 1445  B00B7NPODW      NaN  unknown color  unknown details  missing
# 1446  B00B7NX51K      NaN  unknown color  unknown details  missing
# 1447  B00B7O5B6Q      NaN  unknown color  unknown details  missing
# 1448  B00B7O6NP4      NaN  unknown color  unknown details  missing
# 1449  B00B7O6NRC      NaN  unknown color  unknown details  missing
# 1450  B00B7OM6TG      NaN  unknown color  unknown details  missing
# 1452  B00B7Q2A68      NaN  unknown color  unknown details  missing
# 1453  B00B7QN3BO      NaN  unknown color  unknown details  missing
# 1456  B00B7TBDTU      NaN  unknown color  unknown details  missing
# 1457  B00B7U738Y      NaN  unknown color  unknown details  missing
# 1458  B00B7XM3Y0      NaN  unknown color  unknown details  missing
# 1459  B00B7XNEFC      NaN  unknown color  unknown details  missing
# 1460  B00B822FHK      NaN  unknown color  unknown details  missing
# 1461  B00B89JGPC      NaN  unknown color  unknown details  missing
# 1462  B00B89NYQO      NaN  unknown color  unknown details  missing
# 1463  B00B89PJ4E      NaN  unknown color  unknown details  missing
# 1464  B00B89Y030      NaN  unknown color  unknown details  missing
# 1465  B00B8BYRQ8      NaN  unknown color  unknown details  missing
# 1466  B00B8C8FL0      NaN  unknown color  unknown details  missing
# 1467  B00B8ESDX8      NaN  unknown color  unknown details  missing
# 1469  B00B8IUUIA      NaN  unknown color  unknown details  missing
# 1470  B00B8NWFCE      NaN  unknown color  unknown details  missing
#
#                       name     size        department demographic division  \
# 8     unknown product name  missing  unknown category         NaN      NaN
# 10    unknown product name  missing  unknown category         NaN      NaN
# 11    unknown product name  missing  unknown category         NaN      NaN
# 12    unknown product name  missing  unknown category         NaN      NaN
# 13    unknown product name  missing  unknown category         NaN      NaN
# 16    unknown product name  missing  unknown category         NaN      NaN
# 17    unknown product name  missing  unknown category         NaN      NaN
# 22    unknown product name  missing  unknown category         NaN      NaN
# 24    unknown product name  missing  unknown category         NaN      NaN
# 28    unknown product name  missing  unknown category         NaN      NaN
# 30    unknown product name  missing  unknown category         NaN      NaN
# 32    unknown product name  missing  unknown category         NaN      NaN
# 37    unknown product name  missing  unknown category         NaN      NaN
# 39    unknown product name  missing  unknown category         NaN      NaN
# 43    unknown product name  missing  unknown category         NaN      NaN
# 52    unknown product name  missing  unknown category         NaN      NaN
# 56    unknown product name  missing  unknown category         NaN      NaN
# 58    unknown product name  missing  unknown category         NaN      NaN
# 59    unknown product name  missing  unknown category         NaN      NaN
# 67    unknown product name  missing  unknown category         NaN      NaN
# 69    unknown product name  missing  unknown category         NaN      NaN
# 72    unknown product name  missing  unknown category         NaN      NaN
# 76    unknown product name  missing  unknown category         NaN      NaN
# 77    unknown product name  missing  unknown category         NaN      NaN
# 78    unknown product name  missing  unknown category         NaN      NaN
# 81    unknown product name  missing  unknown category         NaN      NaN
# 83    unknown product name  missing  unknown category         NaN      NaN
# 85    unknown product name  missing  unknown category         NaN      NaN
# 89    unknown product name  missing  unknown category         NaN      NaN
# 92    unknown product name  missing  unknown category         NaN      NaN
# ...                    ...      ...               ...         ...      ...
# 1436  unknown product name  missing  unknown category         NaN      NaN
# 1437  unknown product name  missing  unknown category         NaN      NaN
# 1439  unknown product name  missing  unknown category         NaN      NaN
# 1440  unknown product name  missing  unknown category         NaN      NaN
# 1441  unknown product name  missing  unknown category         NaN      NaN
# 1442  unknown product name  missing  unknown category         NaN      NaN
# 1443  unknown product name  missing  unknown category         NaN      NaN
# 1444  unknown product name  missing  unknown category         NaN      NaN
# 1445  unknown product name  missing  unknown category         NaN      NaN
# 1446  unknown product name  missing  unknown category         NaN      NaN
# 1447  unknown product name  missing  unknown category         NaN      NaN
# 1448  unknown product name  missing  unknown category         NaN      NaN
# 1449  unknown product name  missing  unknown category         NaN      NaN
# 1450  unknown product name  missing  unknown category         NaN      NaN
# 1452  unknown product name  missing  unknown category         NaN      NaN
# 1453  unknown product name  missing  unknown category         NaN      NaN
# 1456  unknown product name  missing  unknown category         NaN      NaN
# 1457  unknown product name  missing  unknown category         NaN      NaN
# 1458  unknown product name  missing  unknown category         NaN      NaN
# 1459  unknown product name  missing  unknown category         NaN      NaN
# 1460  unknown product name  missing  unknown category         NaN      NaN
# 1461  unknown product name  missing  unknown category         NaN      NaN
# 1462  unknown product name  missing  unknown category         NaN      NaN
# 1463  unknown product name  missing  unknown category         NaN      NaN
# 1464  unknown product name  missing  unknown category         NaN      NaN
# 1465  unknown product name  missing  unknown category         NaN      NaN
# 1466  unknown product name  missing  unknown category         NaN      NaN
# 1467  unknown product name  missing  unknown category         NaN      NaN
# 1469  unknown product name  missing  unknown category         NaN      NaN
# 1470  unknown product name  missing  unknown category         NaN      NaN
#
#      subcategory type detail_type
# 8            NaN  NaN         NaN
# 10           NaN  NaN         NaN
# 11           NaN  NaN         NaN
# 12           NaN  NaN         NaN
# 13           NaN  NaN         NaN
# 16           NaN  NaN         NaN
# 17           NaN  NaN         NaN
# 22           NaN  NaN         NaN
# 24           NaN  NaN         NaN
# 28           NaN  NaN         NaN
# 30           NaN  NaN         NaN
# 32           NaN  NaN         NaN
# 37           NaN  NaN         NaN
# 39           NaN  NaN         NaN
# 43           NaN  NaN         NaN
# 52           NaN  NaN         NaN
# 56           NaN  NaN         NaN
# 58           NaN  NaN         NaN
# 59           NaN  NaN         NaN
# 67           NaN  NaN         NaN
# 69           NaN  NaN         NaN
# 72           NaN  NaN         NaN
# 76           NaN  NaN         NaN
# 77           NaN  NaN         NaN
# 78           NaN  NaN         NaN
# 81           NaN  NaN         NaN
# 83           NaN  NaN         NaN
# 85           NaN  NaN         NaN
# 89           NaN  NaN         NaN
# 92           NaN  NaN         NaN
# ...          ...  ...         ...
# 1436         NaN  NaN         NaN
# 1437         NaN  NaN         NaN
# 1439         NaN  NaN         NaN
# 1440         NaN  NaN         NaN
# 1441         NaN  NaN         NaN
# 1442         NaN  NaN         NaN
# 1443         NaN  NaN         NaN
# 1444         NaN  NaN         NaN
# 1445         NaN  NaN         NaN
# 1446         NaN  NaN         NaN
# 1447         NaN  NaN         NaN
# 1448         NaN  NaN         NaN
# 1449         NaN  NaN         NaN
# 1450         NaN  NaN         NaN
# 1452         NaN  NaN         NaN
# 1453         NaN  NaN         NaN
# 1456         NaN  NaN         NaN
# 1457         NaN  NaN         NaN
# 1458         NaN  NaN         NaN
# 1459         NaN  NaN         NaN
# 1460         NaN  NaN         NaN
# 1461         NaN  NaN         NaN
# 1462         NaN  NaN         NaN
# 1463         NaN  NaN         NaN
# 1464         NaN  NaN         NaN
# 1465         NaN  NaN         NaN
# 1466         NaN  NaN         NaN
# 1467         NaN  NaN         NaN
# 1469         NaN  NaN         NaN
# 1470         NaN  NaN         NaN
#
# [976 rows x 13 columns]

# %%
redo_list2 = (list((redo8528[redo8528['department'] == 'unknown category'])['asin'])) + (list((redo10000[redo10000['department'] == 'unknown category'])['asin']))

len(redo_list2)
# Out:
# 2099

# %%
redo_list2[:25]
# Out:
# ['B007WA2TCS',
#  'B007WA2U7W',
#  'B007WA2VB2',
#  'B007WA2ZTA',
#  'B007WA3558',
#  'B007WA38IM',
#  'B007WA38OG',
#  'B007WA397M',
#  'B007WA3B5C',
#  'B007WA3CUQ',
#  'B007WA3GMK',
#  'B007WA3HLK',
#  'B007WA3JE0',
#  'B007WA3PD0',
#  'B007WA48E0',
#  'B007WA49DA',
#  'B007WA4CQ4',
#  'B007WACT6Y',
#  'B007WACX3I',
#  'B007WACY5K',
#  'B007WAD2QU',
#  'B007WADBUC',
#  'B007WADJ7M',
#  'B007WADN4G',
#  'B007WADRBK']

# %%
#redo12009 = pd.DataFrame(list_of_dicts)

# %%
#EDA(redo12009)

# %%
#(redo12009[redo12009['name'] != 'unknown product name']).to_csv('data/redo6.csv')

# %%
#redo12009.to_csv('redo_list3.csv')

# %%
redo12009 = pd.read_csv('scrapes/redo_list3.csv', index_col=[0])
redo12009.head()
# Out:
#          asin                                        description  \
# 0  B007WA2TCS  Currently unavailable.\n        \n        \n  ...
# 1  B007WA2U7W                                                NaN
# 2  B007WA2VB2  Currently unavailable.\n        \n        \n  ...
# 3  B007WA2ZTA  Currently unavailable.\n        \n        \n  ...
# 4  B007WA3558  Currently unavailable.\n        \n        \n  ...
#
#                                                 name
# 0  Allegra K Women V Neck Sleeveless Striped Pane...
# 1                               unknown product name
# 2  Allegra K Women Scoop Neck Drawstring Mid-Calf...
# 3  Allegra K Women Peter Pan 3/4 Sleeve Summer To...
# 4  Allegra K Lady Ruffle Tie Neck Short Sleeves B...

# %%
redo12009['name'].value_counts().head()
# Out:
# unknown product name                                                                                              1864
# uiphgjwexzv                                                                                                          5
# HONB Money Clip Credit Card Holder                                                                                   2
# Metal Factory Sterling Silver Crystal Ball Bead Charm Fits Pandora Chamilia Biagi Trollbeads European Bracelet       2
# Sterling Silver Green Crystal Ball Bead Charm                                                                        2
# Name: name, dtype: int64

# %%
redo_list2.extend(list((redo12009[redo12009['name'] == 'unknown product name'])['asin']))

# %%
len(redo_list2)
# Out:
# 3963

# %% [markdown]
# After scraping all 23000+ items, I noticed some pages that seemed valid were not getting picked up by the scraper. I picked out a few individually to inspect their html and tried rescraping with the below tags.

# %%
t1 = time.time()
print(t1)
list_of_dicts = []
for i in redo_list2[:10]:
    print(f'https://www.amazon.com/gp/product/{i}')
    driver.get(f'https://www.amazon.com/gp/product/{i}')
    soup = BeautifulSoup(driver.page_source, 'lxml') 
    product_info = {}
    try:
        product_info['asin'] = i
        product_info['name'] = soup.find('h1', {'id':'title'}).text.strip()

        product_info['description'] = soup.find('div', {'id':'availability_feature_div'}).text.strip()
        list_of_dicts.append(product_info)
        
    except:
        product_info['asin'] = i
        
        product_info['name'] = 'unknown product name'
        list_of_dicts.append(product_info)
        print(len(list_of_dicts))
    sleep(randint(1,2))
    

print(time.time() - t1)
# Out:
# 1566771501.184383
# https://www.amazon.com/gp/product/B007WA2TCS
# https://www.amazon.com/gp/product/B007WA2U7W
# 2
# https://www.amazon.com/gp/product/B007WA2VB2
# https://www.amazon.com/gp/product/B007WA2ZTA
# https://www.amazon.com/gp/product/B007WA3558
# https://www.amazon.com/gp/product/B007WA38IM
# 6
# https://www.amazon.com/gp/product/B007WA38OG
# 7
# https://www.amazon.com/gp/product/B007WA397M
# 8
# https://www.amazon.com/gp/product/B007WA3B5C
# 9
# https://www.amazon.com/gp/product/B007WA3CUQ
# 10
# 24.65636110305786

# %% [markdown]
# Check length of scrape.

# %%
#redo_new = pd.DataFrame(list_of_dicts)

# %%
pd.DataFrame(list_of_dicts)['name'].value_counts()
# Out:
# unknown product name                                                                               6
# Allegra K Women Scoop Neck Drawstring Mid-Calf Dress Heather Grey S                                1
# Allegra K Women Peter Pan 3/4 Sleeve Summer Top Chiffon Blouse,X-Small / US 2,Pink                 1
# Allegra K Lady Ruffle Tie Neck Short Sleeves Button Down Shirt Light Yellow XS                     1
# Allegra K Women V Neck Sleeveless Striped Panel Flared Short Skater Dresses, Dark Blue, X-Small    1
# Name: name, dtype: int64

# %%
#redo_new.to_csv('redo_list3.csv')

# %%
redo_new = pd.read_csv('scrapes/redo_list3.csv', index_col=[0]).drop(columns='description')
redo_new.head()
# Out:
#          asin                                               name
# 0  B007WA2TCS  Allegra K Women V Neck Sleeveless Striped Pane...
# 1  B007WA2U7W                               unknown product name
# 2  B007WA2VB2  Allegra K Women Scoop Neck Drawstring Mid-Calf...
# 3  B007WA2ZTA  Allegra K Women Peter Pan 3/4 Sleeve Summer To...
# 4  B007WA3558  Allegra K Lady Ruffle Tie Neck Short Sleeves B...

# %%
# redo_new[redo_new['name'] != 'unknown product name'].to_csv('data/redo7.csv')
